# %% [markdown]
# ## Getting started with NumPy
#
#
# ### Exercise 1
# 1. Import numpy package as `np`
# 1. Generate a 3D `ndarray of` size 3x3x3 with integers between 0 to 30 only

# %%
import numpy as np

a = np.random.randint(0, 30, (3,3))

# %% [markdown]
# 1. Find the minmum and maximum number of the ndarray

# %%
# Out:
# 5

# %% [markdown]
# ### Exercise 2 - Swiss data

# %% [markdown]
# ##### Import the `swiss` data set as below.

# %%
sw_url = "https://biostat2.uni.lu/practicals/data/swiss.csv"

swiss = np.genfromtxt(sw_url, delimiter=",", skip_header=1)

# %% [markdown]
# ##### Compute the sum across the data set

# %% [markdown]
# ##### Compute the mean for all columns.
# Assign the results to an array called `means`.

# %% [markdown]
# ##### Substract the `means` from the `swiss` data to normalize the data.
# Assign to `norm_swiss`.

# %% [markdown]
# ##### Print the first five lines of `norm_swiss`.

# %%
# Out:
# array([[ 10.05744681, -33.65957447,  -1.4893617 ,   1.0212766 ,
#         -31.18382979,   2.25744681],
#        [ 12.95744681,  -5.55957447, -10.4893617 ,  -1.9787234 ,
#          43.69617021,   2.25744681],
#        [ 22.35744681, -10.95957447, -11.4893617 ,  -5.9787234 ,
#          52.25617021,   0.25744681],
#        [ 15.65744681, -14.15957447,  -4.4893617 ,  -3.9787234 ,
#          -7.37382979,   0.35744681],
#        [  6.75744681,  -7.15957447,   0.5106383 ,   4.0212766 ,
#         -35.98382979,   0.65744681]])

# %% [markdown]
# ##### Check if the sum of `norm_swiss` is greater than 0.0001.

# %%
# Out:
# False
